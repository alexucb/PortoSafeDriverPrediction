# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
import gc
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
print('loading files...')
train = pd.read_csv('train.csv', na_values=-1)
test = pd.read_csv('test.csv', na_values=-1)
col_to_drop = train.columns[train.columns.str.startswith('ps_calc_')]
train = train.drop(col_to_drop, axis=1)  
test = test.drop(col_to_drop, axis=1)  

for c in train.select_dtypes(include=['float64']).columns:
    train[c]=train[c].astype(np.float32)
    test[c]=test[c].astype(np.float32)
for c in train.select_dtypes(include=['int64']).columns[2:]:
    train[c]=train[c].astype(np.int8)
    test[c]=test[c].astype(np.int8)    

print(train.shape, test.shape)
# Out:
# loading files...
# (595212, 39) (892816, 38)

# %%
# custom objective function (similar to auc)

def gini(y, pred):
    g = np.asarray(np.c_[y, pred, np.arange(len(y)) ], dtype=np.float)
    g = g[np.lexsort((g[:,2], -1*g[:,1]))]
    gs = g[:,0].cumsum().sum() / g[:,0].sum()
    gs -= (len(y) + 1) / 2.
    return gs / len(y)

def gini_xgb(pred, y):
    y = y.get_label()
    return 'gini', gini(y, pred) / gini(y, y)

def gini_lgb(preds, dtrain):
    y = list(dtrain.get_label())
    score = gini(y, preds) / gini(y, y)
    return 'gini', score, True

# %%
# %%time

# xgb
params = {'eta': 0.02, 'max_depth': 4, 'subsample': 0.9, 'colsample_bytree': 0.9, 
          'objective': 'binary:logistic', 'eval_metric': 'auc', 'silent': True}

X = train.drop(['id', 'target'], axis=1)
features = X.columns
X = X.values
y = train['target'].values
sub=test['id'].to_frame()
sub['target']=0

nrounds=2000  # need to change to 2000
kfold = 5  # need to change to 5
skf = StratifiedKFold(n_splits=kfold, random_state=0)
for i, (train_index, test_index) in enumerate(skf.split(X, y)):
    print(' xgb kfold: {}  of  {} : '.format(i+1, kfold))
    X_train, X_valid = X[train_index], X[test_index]
    y_train, y_valid = y[train_index], y[test_index]
    d_train = xgb.DMatrix(X_train, y_train) 
    d_valid = xgb.DMatrix(X_valid, y_valid) 
    watchlist = [(d_train, 'train'), (d_valid, 'valid')]
    xgb_model = xgb.train(params, d_train, nrounds, watchlist, early_stopping_rounds=100, 
                          feval=gini_xgb, maximize=True, verbose_eval=100)
    sub['target'] += xgb_model.predict(xgb.DMatrix(test[features].values), 
                        ntree_limit=xgb_model.best_ntree_limit+50) / (2*kfold)
gc.collect()
sub.head(2)

# lgb
params = {'metric': 'auc', 'learning_rate' : 0.01, 'max_depth':10, 'max_bin':10,  'objective': 'binary', 
          'feature_fraction': 0.8,'bagging_fraction':0.9,'bagging_freq':10,  'min_data': 500}

skf = StratifiedKFold(n_splits=kfold, random_state=1)
for i, (train_index, test_index) in enumerate(skf.split(X, y)):
    print(' lgb kfold: {}  of  {} : '.format(i+1, kfold))
    X_train, X_eval = X[train_index], X[test_index]
    y_train, y_eval = y[train_index], y[test_index]
    lgb_model = lgb.train(params, lgb.Dataset(X_train, label=y_train), nrounds, 
                  lgb.Dataset(X_eval, label=y_eval), verbose_eval=100, 
                  feval=gini_lgb, early_stopping_rounds=100)
    sub['target'] += lgb_model.predict(test[features].values, 
                        num_iteration=lgb_model.best_iteration) / (2*kfold)
    
sub.to_csv('sub10.csv', index=False, float_format='%.5f') 
gc.collect()
sub.head(2)
# Out:
#  xgb kfold: 1  of  5 :
# [0]	train-gini:0.202082	valid-gini:0.205887
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [100]	train-gini:0.248736	valid-gini:0.240129
# [200]	train-gini:0.277074	valid-gini:0.258586
# [300]	train-gini:0.297776	valid-gini:0.270673
# [400]	train-gini:0.312015	valid-gini:0.27694
# [500]	train-gini:0.322203	valid-gini:0.279789
# [600]	train-gini:0.330076	valid-gini:0.281123
# [700]	train-gini:0.337154	valid-gini:0.281701
# [800]	train-gini:0.343712	valid-gini:0.281872
# [900]	train-gini:0.350425	valid-gini:0.281703
# [1000]	train-gini:0.356594	valid-gini:0.282228
# [1100]	train-gini:0.362406	valid-gini:0.281569
# Stopping. Best iteration:
# [1014]	train-gini:0.357331	valid-gini:0.282276
#
#  xgb kfold: 2  of  5 :
# [0]	train-gini:0.201049	valid-gini:0.198643
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [100]	train-gini:0.24984	valid-gini:0.234957
# [200]	train-gini:0.275303	valid-gini:0.257248
# [300]	train-gini:0.296437	valid-gini:0.272205
# [400]	train-gini:0.310959	valid-gini:0.279698
# [500]	train-gini:0.321106	valid-gini:0.283082
# [600]	train-gini:0.329318	valid-gini:0.284522
# [700]	train-gini:0.336685	valid-gini:0.286137
# [800]	train-gini:0.343997	valid-gini:0.287196
# [900]	train-gini:0.350634	valid-gini:0.287673
# [1000]	train-gini:0.357063	valid-gini:0.288092
# [1100]	train-gini:0.362708	valid-gini:0.288438
# Stopping. Best iteration:
# [1084]	train-gini:0.361988	valid-gini:0.288486
#
#  xgb kfold: 3  of  5 :
# [0]	train-gini:0.200868	valid-gini:0.197434
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [100]	train-gini:0.248854	valid-gini:0.24202
# [200]	train-gini:0.27678	valid-gini:0.258707
# [300]	train-gini:0.297594	valid-gini:0.271355
# [400]	train-gini:0.311016	valid-gini:0.277333
# [500]	train-gini:0.321302	valid-gini:0.279403
# [600]	train-gini:0.329926	valid-gini:0.280768
# [700]	train-gini:0.337405	valid-gini:0.2814
# [800]	train-gini:0.344494	valid-gini:0.281505
# Stopping. Best iteration:
# [737]	train-gini:0.339894	valid-gini:0.281577
#
#  xgb kfold: 4  of  5 :
# [0]	train-gini:0.182462	valid-gini:0.170786
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [100]	train-gini:0.247394	valid-gini:0.232899
# [200]	train-gini:0.273308	valid-gini:0.258116
# [300]	train-gini:0.294041	valid-gini:0.273879
# [400]	train-gini:0.308823	valid-gini:0.282829
# [500]	train-gini:0.319162	valid-gini:0.286882
# [600]	train-gini:0.328067	valid-gini:0.288556
# [700]	train-gini:0.335672	valid-gini:0.289961
# [800]	train-gini:0.342755	valid-gini:0.291086
# [900]	train-gini:0.348811	valid-gini:0.29124
# [1000]	train-gini:0.354646	valid-gini:0.291489
# [1100]	train-gini:0.360357	valid-gini:0.291919
# [1200]	train-gini:0.36635	valid-gini:0.292146
# [1300]	train-gini:0.371637	valid-gini:0.291885
# Stopping. Best iteration:
# [1200]	train-gini:0.36635	valid-gini:0.292146
#
#  xgb kfold: 5  of  5 :
# [0]	train-gini:0.201853	valid-gini:0.189866
# Multiple eval metrics have been passed: 'valid-gini' will be used for early stopping.
#
# Will train until valid-gini hasn't improved in 100 rounds.
# [100]	train-gini:0.250893	valid-gini:0.236408
# [200]	train-gini:0.278687	valid-gini:0.254415
# [300]	train-gini:0.29886	valid-gini:0.264767
# [400]	train-gini:0.312612	valid-gini:0.270231
# [500]	train-gini:0.322085	valid-gini:0.272767
# [600]	train-gini:0.330459	valid-gini:0.274143
# [700]	train-gini:0.338092	valid-gini:0.275208
# [800]	train-gini:0.344679	valid-gini:0.275693
# [900]	train-gini:0.350803	valid-gini:0.275851
# [1000]	train-gini:0.356595	valid-gini:0.276143
# [1100]	train-gini:0.362036	valid-gini:0.276465
# [1200]	train-gini:0.367913	valid-gini:0.276762
# [1300]	train-gini:0.373163	valid-gini:0.276593
# Stopping. Best iteration:
# [1220]	train-gini:0.369059	valid-gini:0.276938
#
#  lgb kfold: 1  of  5 :
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.627386	valid_0's gini: 0.254771
# [200]	valid_0's auc: 0.628723	valid_0's gini: 0.257445
# [300]	valid_0's auc: 0.630861	valid_0's gini: 0.261722
# [400]	valid_0's auc: 0.634077	valid_0's gini: 0.268154
# [500]	valid_0's auc: 0.636785	valid_0's gini: 0.27357
# [600]	valid_0's auc: 0.638621	valid_0's gini: 0.277242
# [700]	valid_0's auc: 0.640062	valid_0's gini: 0.280124
# [800]	valid_0's auc: 0.640698	valid_0's gini: 0.281395
# [900]	valid_0's auc: 0.64103	valid_0's gini: 0.28206
# [1000]	valid_0's auc: 0.641319	valid_0's gini: 0.282638
# [1100]	valid_0's auc: 0.64156	valid_0's gini: 0.283121
# [1200]	valid_0's auc: 0.641636	valid_0's gini: 0.283273
# Early stopping, best iteration is:
# [1180]	valid_0's auc: 0.641705	valid_0's gini: 0.283411
#  lgb kfold: 2  of  5 :
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.625543	valid_0's gini: 0.251087
# [200]	valid_0's auc: 0.627589	valid_0's gini: 0.255179
# [300]	valid_0's auc: 0.630495	valid_0's gini: 0.260989
# [400]	valid_0's auc: 0.634589	valid_0's gini: 0.269179
# [500]	valid_0's auc: 0.637921	valid_0's gini: 0.275841
# [600]	valid_0's auc: 0.639945	valid_0's gini: 0.279891
# [700]	valid_0's auc: 0.64122	valid_0's gini: 0.28244
# [800]	valid_0's auc: 0.642102	valid_0's gini: 0.284205
# [900]	valid_0's auc: 0.642608	valid_0's gini: 0.285216
# [1000]	valid_0's auc: 0.642824	valid_0's gini: 0.285648
# [1100]	valid_0's auc: 0.643028	valid_0's gini: 0.286055
# [1200]	valid_0's auc: 0.643222	valid_0's gini: 0.286443
# [1300]	valid_0's auc: 0.64325	valid_0's gini: 0.2865
# Early stopping, best iteration is:
# [1270]	valid_0's auc: 0.643269	valid_0's gini: 0.286538
#  lgb kfold: 3  of  5 :
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.62659	valid_0's gini: 0.25318
# [200]	valid_0's auc: 0.627508	valid_0's gini: 0.255015
# [300]	valid_0's auc: 0.630522	valid_0's gini: 0.261044
# [400]	valid_0's auc: 0.633475	valid_0's gini: 0.266951
# [500]	valid_0's auc: 0.636402	valid_0's gini: 0.272805
# [600]	valid_0's auc: 0.638743	valid_0's gini: 0.277485
# [700]	valid_0's auc: 0.640231	valid_0's gini: 0.280462
# [800]	valid_0's auc: 0.640627	valid_0's gini: 0.281255
# [900]	valid_0's auc: 0.640946	valid_0's gini: 0.281892
# [1000]	valid_0's auc: 0.641074	valid_0's gini: 0.282149
# [1100]	valid_0's auc: 0.641197	valid_0's gini: 0.282394
# Early stopping, best iteration is:
# [1041]	valid_0's auc: 0.641215	valid_0's gini: 0.28243
#  lgb kfold: 4  of  5 :
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.625359	valid_0's gini: 0.250717
# [200]	valid_0's auc: 0.627118	valid_0's gini: 0.254235
# [300]	valid_0's auc: 0.631139	valid_0's gini: 0.262278
# [400]	valid_0's auc: 0.635698	valid_0's gini: 0.271396
# [500]	valid_0's auc: 0.639607	valid_0's gini: 0.279214
# [600]	valid_0's auc: 0.642438	valid_0's gini: 0.284875
# [700]	valid_0's auc: 0.64405	valid_0's gini: 0.2881
# [800]	valid_0's auc: 0.644972	valid_0's gini: 0.289945
# [900]	valid_0's auc: 0.645767	valid_0's gini: 0.291535
# [1000]	valid_0's auc: 0.646064	valid_0's gini: 0.292127
# [1100]	valid_0's auc: 0.646234	valid_0's gini: 0.292469
# [1200]	valid_0's auc: 0.646355	valid_0's gini: 0.29271
# [1300]	valid_0's auc: 0.646279	valid_0's gini: 0.292558
# Early stopping, best iteration is:
# [1204]	valid_0's auc: 0.646369	valid_0's gini: 0.292738
#  lgb kfold: 5  of  5 :
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.624897	valid_0's gini: 0.249795
# [200]	valid_0's auc: 0.626106	valid_0's gini: 0.252214
# [300]	valid_0's auc: 0.628625	valid_0's gini: 0.25725
# [400]	valid_0's auc: 0.631361	valid_0's gini: 0.262723
# [500]	valid_0's auc: 0.633888	valid_0's gini: 0.267776
# [600]	valid_0's auc: 0.635849	valid_0's gini: 0.271699
# [700]	valid_0's auc: 0.637394	valid_0's gini: 0.274788
# [800]	valid_0's auc: 0.637932	valid_0's gini: 0.275864
# [900]	valid_0's auc: 0.638052	valid_0's gini: 0.276104
# [1000]	valid_0's auc: 0.638295	valid_0's gini: 0.276591
# [1100]	valid_0's auc: 0.638483	valid_0's gini: 0.276967
# [1200]	valid_0's auc: 0.638735	valid_0's gini: 0.27747
# [1300]	valid_0's auc: 0.63893	valid_0's gini: 0.277859
# [1400]	valid_0's auc: 0.638935	valid_0's gini: 0.27787
# Early stopping, best iteration is:
# [1347]	valid_0's auc: 0.638999	valid_0's gini: 0.277998
# Wall time: 1h 1min 5s
